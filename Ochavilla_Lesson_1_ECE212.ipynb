# %% [markdown]
# # LESSON 1: INTRODUCTION TO PYTHON

# %% [markdown]
# ## Introduction
# ---
#
# Python is a deciphered, object-arranged, significant level programming language with dynamic semantics.Python's simple, simple to learn syntax emphasizes readability and in this manner lessens the expense of program support. Python upholds modules and bundles, which encourages program particularity and code reuse. The Python translator and the broad standard library are accessible in source or paired structure without charge for every single significant stage, and can be uninhibitedly disseminated
#
# So in this lesson, this coursepack will show us how to comprehend and make program in Python. Understanding computer programs requires algorithmic, unthinking reasoning. In this way, understanding computer codes includes a great deal of mental recreation of what will really occur, not what you wish would happen. This additionally requires innovative critical thinking, this implies the capacity to plan, ponder arrangements, and express it unmistakably and precisely.

# %% [markdown]
# ### Activity
#
# #### 1.) Why do you think understanding computer programs is relevant in our time today especially in the new normal?
#
# I think understanding PC programs is important presently today particularly in the new ordinary as Steve Jobs once stated, "Everyone in this nation ought to figure out how to program a PC since it shows you how to think." Computer programing is a hugely versatile device that you can use to do shocking things that are by and large either manual and laborsome or are essentially extraordinary. PC programming makes things simpler for us, by coding it creates organized and inventive deduction, and by learning programs it instructs us to be tenacious. Particularly in this new ordinary phase of life, writing computer programs is benevolent the pertinent to us all. Since we are restricted to get things done external our premises, we will in general trade off it by utilizing our advanced contraptions. In this new stage, we will in general learn courses on the web and think innovatively on making our online life partner and energizing.
#
# #### 2.) If you were able to learn computer program, what program will you code? Why?
#
# In the event that I had the option to learn PC program, I think I'll stick on learning python. As it was said that Python language isn't just an elevated level programming language but on the other hand is adaptable and it is additionally being instructed right now.
#
# #### 3.) What would be your pirmary motivation in learning programming?
#
# My essential inspiration would be this will help us a great deal in evaluating our career later on. Beside that, this new ordinary situation could likewise help in empowering on confronting exercises that bargains on PCs.

# %% [markdown]
# ## Application

# %% [markdown]
# ## Ask Yourself:
#
# #### 1.) Why do you think Python is the most applicable programming language for scientific computing?
#
# Programming dialects have been around for a long time, and dependably watches the dispatch of another dialects significantly motivating fashioners. Python is quickly ascending to the bleeding edge of the most standard programming dialects on the planet and its exceptional advancement is indisputably showed up on Stock Overflow than other programming dialects. Why Python? Composing Python code is straightforward which rates up progress beside that perusing Python code is in like manner regular. Most importantly, Python additionally gives us endeavored and attempted flexibility. This makes Python confirmation perhaps the most looked in the wake of programming accreditations.
#
# #### 2.) If Python can build anything, where do you think Python is not applicable for?
#
# Disregarding the way that Python can construct anything, there are moreover a couple of shortcomings. Python has moderate execution speed, which infers it works with a mediator, and not with a compiler. Python executes more delayed than C, C++, Java and various dialects. Second, it has tremendous memory use, accordingly it isn't sensible to use for development under confined memory restriction. Third, it isn't sensible for Mobile and Game improvement on account of the usage of more memory and its moderate taking care of speed appeared differently in relation to other programming tongues. Ultimately, it is difficult to test, since it is a mediator based language, it is hard to run tests on code written in Python.

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 1: Mailing Address (Solved, 9 Lines)
#
# Create a program that displays your name and complete mailing addresss. The address should be printed in the format that is normally used in the area where you live. You program does not need to ready any input from the user.

# %%
print("Full Name: Carl Orvey Daludado Ochavilla")
print("Address: Guijo St., Poly Subdivision, Matina Aplaya")
print ("Davao City, Davao Del Sur")
print ("Contact Number: 09478297630")
print ("Email Address: codochavilla@usep.edu.ph")
print("8100")
print ("Mindanao")
print ("Philippines")
# Out:
# Full Name: Carl Orvey Daludado Ochavilla
# Address: Guijo St., Poly Subdivision, Matina Aplaya
# Davao City, Davao Del Sur
# Contact Number: 09478297630
# Email Address: codochavilla@usep.edu.ph
# 8100
# Mindanao
# Philippines

# %% [markdown]
# ## Exercise 2: Area of a Room (Solved, 13 Lines)
#
# Write a program that asks the user to enter the width and length of a room. Once these values have been read, your program should compute and display the area of the room. The length and the width will be entered as floating-point numbers. Include units in your prompt and output message; either feet or meters, depending on which unit you are more comfortable working with.

# %%
#compute the area of the room

#read the dimensions from the user
length = float(input("Enter the length of the room in meters:"))
width = float(input("Enter the width of the room in meters:"))

#compute the area of the room
area = length * width

#display the results
print("The area of the room is", area, "squared meters")
# Out:
# Enter the length of the room in meters:5
# Enter the width of the room in meters:6
# The area of the room is 30.0 squared meters

# %% [markdown]
# ## Exercise 3: Arithmetic (Solved, 22 Lines)
#
#
# Exercise 3: Arithmetic (Solved, 22 Lines)
# Create a program that reads two integers, a and b, from the user. Your program should compute and display:
#
# •The sum of a and b
#
# •The difference when b is subtracted from a
#
# •The product of a and b
#
# •The quotient when a is divided by b
#
# •The remainder when a is divided by b
#
# •The result of log10 a
#
# •The result of ab
#
# Hint: You will probably find the log10 function in the math module helpful for computing the second last item in the list.

# %%
# four integers
a = float (input("Value of a: "))
b =  float (input("Value of b:  "))
 
sum = a + b
print ("Sum of a and b: ", sum)

difference = a - b
print ("b subtracted to a: ", difference)

product = a*b
print ("Product of a and b: ", product)

quotient = a/b
print ("quotient of a and b: ",quotient)

remainder = a%b
print ("Remainder of a divided by b: ", remainder)

import math
log = math.log10(a)
print ("log10a: ", log)

import math
log = math.log10(a*b)
print ("log10a*b : ", log)
# Out:
# Value of a: 4
# Value of b:  5
# Sum of a and b:  9.0
# b subtracted to a:  -1.0
# Product of a and b:  20.0
# quotient of a and b:  0.8
# Remainder of a divided by b:  4.0
# log10a:  0.6020599913279624
# log10a*b :  1.3010299956639813

# %% [markdown]
# ## Exercise 4: Area and Volume (15 Lines)
#
# Write a program that begins by reading a radius, r, from the user. The program will continue by computing and displaying the area of a circle with radius r and the volume of a sphere with radius r. Use the pi constant in the math module in your calculations.

# %%
#area of a circle, and the volume of a sphere by just defining radius r.

import math
r = float(input("Enter the radius in meter: "))

area = math.pi * r * r
volume = (4/3) * math.pi * r * r * r

print("The area of a circle is:",area,"squared meters.")
print("The volume of a sphere is:",volume,"cubic meters.")
# Out:
# Enter the radius in meter: 6
# The area of a circle is: 113.09733552923255 squared meters.
# The volume of a sphere is: 904.7786842338604 cubic meters.
